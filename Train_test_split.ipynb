# %% [markdown]
# <a href="https://colab.research.google.com/github/mdeasinkhandokar/Machine_Learning/blob/main/Train_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/CSV/carprices.csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %% [markdown]
# **Car Milleage Vs Sell Price**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.title('Car Mileage vs Sell Price')
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %% [markdown]
# **Car Age Vs Sell Price($)**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('Car Age')
plt.ylabel('Sell Price($)')
plt.title('Car Age vs Sell Price')
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %% [markdown]
# **Training and Test**

# %%
X=df[['Mileage','Age(yrs)']]

# %%
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 13    58780         4
# 8     91000         8
# 18    87600         8
# 19    52000         5
# 1     35000         3
# 12    59000         5
# 11    79000         7
# 4     46000         4
# 17    69000         5
# 2     57000         5
# 14    82450         7
# 5     59000         5
# 7     72000         6
# 15    25400         3
# 0     69000         6
# 3     22500         2

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 9     67000         6
# 16    28000         2
# 10    83000         7
# 6     52000         5

# %%
y_train
# Out:
# 13    27500
# 8     12000
# 18    12800
# 19    28200
# 1     34000
# 12    26000
# 11    19500
# 4     31500
# 17    19700
# 2     26100
# 14    19400
# 5     26750
# 7     19300
# 15    35000
# 0     18000
# 3     40000
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 9     22000
# 16    35500
# 10    18700
# 6     32000
# Name: Sell Price($), dtype: int64

# %% [markdown]
# **Lets run  linear regression model now**

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 9     67000         6
# 16    28000         2
# 10    83000         7
# 6     52000         5

# %%
clf.predict(X_test)
# Out:
# array([21902.96114481, 37518.92057165, 16250.62476148, 27275.56208388])

# %%
y_test
# Out:
# 9     22000
# 16    35500
# 10    18700
# 6     32000
# Name: Sell Price($), dtype: int64

# %% [markdown]
# **Random State Argument**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)
X_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 18    87600         8
